# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_json('training.json')

# %%
df2=pd.read_csv('New horse data.csv')

# %%
df1.head()
# Out:
#      venue trackCondition  trackRating       date  raceNum  distance  \
# 0  BELMONT           SOFT          6.0 2017-08-05        1      1200
# 1  BELMONT           SOFT          6.0 2017-08-05        1      1200
# 2  BELMONT           SOFT          6.0 2017-08-05        1      1200
# 3  BELMONT           SOFT          6.0 2017-08-05        1      1200
# 4  BELMONT           SOFT          6.0 2017-08-05        1      1200
#
#    starters class   weather  temperature  ...  changeInOddsNightBefore  \
# 0        13   Mdn  OVERCAST         17.1  ...                 0.000000
# 1        13   Mdn  OVERCAST         17.1  ...                 0.000000
# 2        13   Mdn  OVERCAST         17.1  ...                 0.000000
# 3        13   Mdn  OVERCAST         17.1  ...                 0.064516
# 4        13   Mdn  OVERCAST         17.1  ...                 0.142857
#
#    changeInOddsMorning lastStartDistanceChange jockeyLast25StrikeRate  \
# ...

# %%
df2.head()
# Out:
#    Unnamed: 0    VCODE GOING  trackRating        date  raceNum  DIST  STARTS  \
# 0           0  BELMONT  SOFT          6.0  2017-08-05        1  1200      13
# 1           1  BELMONT  SOFT          6.0  2017-08-05        1  1200      13
# 2           2  BELMONT  SOFT          6.0  2017-08-05        1  1200      13
# 3           3  BELMONT  SOFT          6.0  2017-08-05        1  1200      13
# 4           4  BELMONT  SOFT          6.0  2017-08-05        1  1200      13
#
#   class   weather  ...  changeInOddsNightBefore  changeInOddsMorning  \
# 0   Mdn  OVERCAST  ...                 0.000000             1.470588
# 1   Mdn  OVERCAST  ...                 0.000000             1.266667
# 2   Mdn  OVERCAST  ...                 0.000000            -0.285714
# 3   Mdn  OVERCAST  ...                 0.064516             0.483871
# 4   Mdn  OVERCAST  ...                 0.142857             0.500000
#
#    lastStartDistanceChange jockeyLast25StrikeRate jockeyLast25PlaceStrikeRate  \
# ...

# %%
df2.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df1.shape
# Out:
# (33950, 54)

# %%
df2.shape
# Out:
# (33950, 54)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33950 entries, 0 to 33949
# Data columns (total 54 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   venue                         33950 non-null  object
#  1   trackCondition                33880 non-null  object
#  2   trackRating                   33488 non-null  float64
#  3   date                          33950 non-null  datetime64[ns]
#  4   raceNum                       33950 non-null  int64
#  5   distance                      33950 non-null  int64
#  6   starters                      33950 non-null  int64
#  7   class                         33950 non-null  object
#  8   weather                       33807 non-null  object
#  9   temperature                   32817 non-null  float64
#  10  humidity                      32817 non-null  float64
#  11  windspeed                     32817 non-null  float64
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33950 entries, 0 to 33949
# Data columns (total 54 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   VCODE                         33950 non-null  object
#  1   GOING                         33880 non-null  object
#  2   trackRating                   33488 non-null  float64
#  3   date                          33950 non-null  object
#  4   raceNum                       33950 non-null  int64
#  5   DIST                          33950 non-null  int64
#  6   STARTS                        33950 non-null  int64
#  7   class                         33950 non-null  object
#  8   weather                       33807 non-null  object
#  9   temperature                   32817 non-null  float64
#  10  humidity                      32817 non-null  float64
#  11  windspeed                     32817 non-null  float64
# ...

# %%
df1
# Out:
#                 venue trackCondition  trackRating       date  raceNum  \
# 0             BELMONT           SOFT          6.0 2017-08-05        1
# 1             BELMONT           SOFT          6.0 2017-08-05        1
# 2             BELMONT           SOFT          6.0 2017-08-05        1
# 3             BELMONT           SOFT          6.0 2017-08-05        1
# 4             BELMONT           SOFT          6.0 2017-08-05        1
# ...               ...            ...          ...        ...      ...
# 33945  SUNSHINE COAST           GOOD          3.0 2018-08-25        9
# 33946  SUNSHINE COAST           GOOD          3.0 2018-08-25        9
# 33947  SUNSHINE COAST           GOOD          3.0 2018-08-25        9
# 33948  SUNSHINE COAST           GOOD          3.0 2018-08-25        9
# 33949  SUNSHINE COAST           GOOD          3.0 2018-08-25        9
#
#        distance  starters class   weather  temperature  ...  \
# 0          1200        13   Mdn  OVERCAST         17.1  ...
# ...

# %%
data_dict = dict({'venue':'VCODE',
                  'trackCondition':'GOING',
                  'racenum':'RNO',
                  'distance':'DIST',
'starters':'STARTS',
'jockeyname':'JOCKEY',
'trainername':'TRAINER',
'age':'AGE','prizeMoney':'RACESTAKES',
'careerWINS':'WINS',
'careerPlace':'TBASE',
'distanceWin':'TDW',
'fastWin':'FW',
'goodWin':'GW',
'deadWin':'GW',
'slowWin':'SW',
'heavyWin':'HW',
'heavyWin':'HW',
'rating':'XPEAK',
'bettingOdds':'SP_Odds',
'result':'POS'})

# %% [markdown]
# # Creating the list of the columns

# %%
lst1=list(df2.columns)

# %%
lst2=list(df1.columns)

# %%
data1= list(df1.reindex(['venue','trackCondition','raceNum','distance',
'starters',
'jockeyName',
'trainerName',
'age','prizeMoney',
'careerWIN',
'careerPlace',
'distanceWin',
'fastWin',
'goodWin',
'deadWin',
'slowWin',
'heavyWin',
'rating',
'bettingOdds',
'result']))

# %%
data1
# Out:
# ['venue',
#  'trackCondition',
#  'raceNum',
#  'distance',
#  'starters',
#  'jockeyName',
#  'trainerName',
#  'age',
#  'prizeMoney',
#  'careerWIN',
#  'careerPlace',
#  'distanceWin',
#  'fastWin',
#  'goodWin',
#  'deadWin',
#  'slowWin',
#  'heavyWin',
#  'rating',
#  'bettingOdds',
#  'result']

# %%
data2=list(df2.reindex(['VCODE','GOING','RNO','DIST',
'STARTS',
'JOCKEY',
'TRAINER',
'AGE','RACESTAKES',
'WINS',
'TBASE',
'TDW',
'FW',
'GW',
 'dw',      
'SW',
'HW',
'XPEAK',
'SP_Odds',
'POS']))

# %%
len(data2)
# Out:
# 20

# %%
import fuzzymatcher

# %%
matched_results = fuzzymatcher.fuzzy_left_join(df1,df2,data1,data2)

# %%
cols=['best_match_score','VCODE','GOING','RNO','DIST',
'STARTS',
'JOCKEY',
'TRAINER',
'AGE','RACESTAKES',
'WINS',
'TBASE',
'TDW',
'FW',
'GW',
'GW',
'SW',
'HW',
'HW',
'XPEAK',
'SP_Odds',
'POS']

# %%
matched_results
# Out:
#        best_match_score   __id_left   __id_right           venue  \
# 0              3.107909      0_left      0_right         BELMONT
# 1              2.877573      1_left      1_right         BELMONT
# 2              3.264316      2_left      2_right         BELMONT
# 3              2.736105      3_left      3_right         BELMONT
# 4              2.834690      4_left      4_right         BELMONT
# ...                 ...         ...          ...             ...
# 33949          2.467628  33945_left  33945_right  SUNSHINE COAST
# 33950          3.462893  33946_left  33946_right  SUNSHINE COAST
# 33951          3.435507  33947_left  33947_right  SUNSHINE COAST
# 33952          2.372713  33948_left  33948_right  SUNSHINE COAST
# 33953          3.023673  33949_left  33949_right  SUNSHINE COAST
#
#       trackCondition  trackRating_left  date_left  raceNum_left  distance  \
# 0               SOFT               6.0 2017-08-05             1      1200
# ...

# %%
matched_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33950 entries, 0 to 33953
# Columns: 111 entries, best_match_score to POS
# dtypes: datetime64[ns](1), float64(69), int64(20), object(21)
# memory usage: 29.0+ MB

# %%
# Calculating the similarities using two lists similiarity

# %%
from two_lists_similarity import Calculate_Similarity as cs

# %%
cobj = cs(data2,data1)

# %%
cobj.fuzzy_match_output(output_csv_name = 'newhorse.csv')
# Out:
# Initiating fuzzy matching.......
# ------------------------------------------------
# Input column name : venue
# Similarity Ratios when compared with the similar reference list items are as below :  [('venueWin', 90), ('venuePlace', 90), ('venueDistanceWin', 90), ('venueDistancePlace', 90), ('raceNum', 50)]
# Associated Reference list item with highest similarity :
# ('venueWin', 90)
# ------------------------------------------------
# Input column name : trackCondition
# Similarity Ratios when compared with the similar reference list items are as below :  [('DIST', 68), ('trackRating', 64), ('VCODE', 54), ('raceNum', 51), ('TRAINER', 48)]
# Associated Reference list item with highest similarity :
# ('DIST', 68)
# ------------------------------------------------
# Input column name : trackRating
# ...

# %%
similarity=pd.read_csv('newhorse.csv')

# %%
similarity[similarity['similarity_score']>.7]
# Out:
#                  input_list_item         similar_ref_list_item  \
# 0                          venue                      venueWin
# 2                    trackRating                   trackRating
# 3                           date                          date
# 4                        raceNum                       raceNum
# 5                       distance                          DIST
# 6                       starters                        STARTS
# 7                          class                         class
# 8                        weather                       weather
# 9                    temperature                   temperature
# 10                      humidity                      humidity
# 11                     windspeed                     windspeed
# 12                     horseName                         HORSE
# 13                    jockeyName                        JOCKEY
# 14                   trainerName                       TRAINER
# ...
